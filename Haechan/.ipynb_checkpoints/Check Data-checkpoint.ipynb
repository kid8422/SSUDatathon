# %%
import os

from mysql import connector
from dotenv import load_dotenv

# Access environment variables
load_dotenv()

NAME = os.getenv("DB_NAME")
USER = os.getenv("DB_USER")
PASSWORD = os.getenv("DB_PASSWORD")
IP = os.getenv("DB_IP")
PORT = os.getenv("DB_PORT")

# %%
class Database:
    _connection = None  # 클래스 변수로 연결 상태 관리

    @staticmethod
    def get_connection():
        if Database._connection is None or not Database._connection.is_connected():
            Database._connection = connector.connect(
                database = NAME,
                user = USER,
                password = PASSWORD,
                host = IP,
                port = PORT
            )
        return Database._connection

# %%
def execute(query, values=None):
    try:
        conn = Database.get_connection()
        cursor = conn.cursor()

        # values가 있으면 쿼리와 함께 전달
        if values:
            cursor.execute(query, values)
        else:
            cursor.execute(query)

        rows = cursor.fetchall()
        for row in rows:
            print(row)

        cursor.close()
    except connector.Error as e:
        print(f"Error: {e}")

# %%
execute("SHOW TABLES")
# Out:
# ('DDC_count',)
# ('ISBN_rent_count',)
# ('None_ISBN_rent_count',)
# ('auth_group',)
# ('auth_group_permissions',)
# ('auth_permission',)
# ('auth_user',)
# ('auth_user_groups',)
# ('auth_user_user_permissions',)
# ('book',)
# ('django_admin_log',)
# ('django_content_type',)
# ('django_migrations',)
# ('django_session',)
# ('recent_rent',)
# ('rent',)
# ('rent_count',)

# %%
import pandas as pd
import numpy as np

# %%
# 단행본(도서)정보.txt
book_df = pd.read_csv('../Data/단행본(도서)정보.txt', sep=',', encoding='EUC-KR')
book_df[:3]
# Out:
#         도서ID        등록일자    수서방법 분류코드           ISBN  \
# 0  SS_270312  2017-09-13    학과신청  194  9782020658706
# 1  SS_233793  2008-10-13  수서정보없음  160  9788995605189
# 2  SS_233788  2008-10-13  수서정보없음  160  9788995605189
#
#                                                   서명  \
# 0  Le courage de la verite :le gouvernement de so...
# 1                                         김나지움 논리학입문
# 2                                         김나지움 논리학입문
#
#                                저자        출판사  출판년도  소장위치
# 0                Foucault, Michel  Gallimard  2009  4층인문
# 1  Hegel, Georg Wilhelm Friedrich        용의숲  2008  보존서고
# 2  Hegel, Georg Wilhelm Friedrich        용의숲  2008  4층인문

# %%
for i in range(1, len(book_df)):
    query = """
    INSERT INTO book 
    (ID, registration, get_course, DDC, ISBN, title, author, publisher, publication_year, location) 
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
    """
    values = (
        book_df.iloc[i, 0], book_df.iloc[i, 1], book_df.iloc[i, 2], book_df.iloc[i, 3],
        book_df.iloc[i, 4], book_df.iloc[i, 5], book_df.iloc[i, 6], book_df.iloc[i, 7],
        book_df.iloc[i, 8], book_df.iloc[i, 9]
    )
    execute(query, values)
# Out:
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'nan' in 'VALUES'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: No result set to fetch from.
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: MySQL Connection not available.
# Error: No result set to fetch from.
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'nan' in 'VALUES'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: MySQL Connection not available.
# Error: No result set to fetch from.
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'nan' in 'VALUES'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# Error: 1054 (42S22): Unknown column 'registration' in 'INSERT INTO'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 12
#       2 query = """
#       3 INSERT INTO book
#       4 (ID, registration, get_course, DDC, ISBN, title, author, publisher, publication_year, location)
#       5 VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
#       6 """
#       7 values = (
#       8     book_df.iloc[i, 0], book_df.iloc[i, 1], book_df.iloc[i, 2], book_df.iloc[i, 3],
#       9     book_df.iloc[i, 4], book_df.iloc[i, 5], book_df.iloc[i, 6], book_df.iloc[i, 7],
#      10     book_df.iloc[i, 8], book_df.iloc[i, 9]
#      11 )
# ---> 12 execute(query, values)
#
# Cell In[3], line 3, in execute(query, values)
#       1 def execute(query, values=None):
#       2     try:
# ----> 3         conn = Database.get_connection()
#       4         cursor = conn.cursor()
#       6         # values가 있으면 쿼리와 함께 전달
#
# Cell In[2], line 7, in Database.get_connection()
#       4 @staticmethod
#       5 def get_connection():
#       6     if Database._connection is None or not Database._connection.is_connected():
# ----> 7         Database._connection = connector.connect(
#       8             database = NAME,
#       9             user = USER,
#      10             password = PASSWORD,
#      11             host = IP,
#      12             port = PORT
#      13         )
#      14     return Database._connection
#
# File ~/miniconda3/envs/datathon/lib/python3.11/site-packages/mysql/connector/__init__.py:179, in connect(*args, **kwargs)
#     177     return CMySQLConnection(*args, **kwargs)
#     178 else:
# --> 179     return MySQLConnection(*args, **kwargs)
#
# File ~/miniconda3/envs/datathon/lib/python3.11/site-packages/mysql/connector/connection.py:95, in MySQLConnection.__init__(self, *args, **kwargs)
#      92 self._pool_config_version = None
#      94 if len(kwargs) > 0:
# ---> 95     self.connect(**kwargs)
#
# File ~/miniconda3/envs/datathon/lib/python3.11/site-packages/mysql/connector/abstracts.py:717, in MySQLConnectionAbstract.connect(self, **kwargs)
#     715 self.disconnect()
#     716 self._open_connection()
# --> 717 self._post_connection()
#
# File ~/miniconda3/envs/datathon/lib/python3.11/site-packages/mysql/connector/abstracts.py:692, in MySQLConnectionAbstract._post_connection(self)
#     685 def _post_connection(self):
#     686     """Executes commands after connection has been established
#     687
#     688     This method executes commands after the connection has been
#     689     established. Some setting like autocommit, character set, and SQL mode
#     690     are set using this method.
#     691     """
# --> 692     self.set_charset_collation(self._charset_id)
#     693     self.autocommit = self._autocommit
#     694     if self._time_zone:
#
# File ~/miniconda3/envs/datathon/lib/python3.11/site-packages/mysql/connector/abstracts.py:650, in MySQLConnectionAbstract.set_charset_collation(self, charset, collation)
#     646 elif collation:
#     647     (self._charset_id, charset_name, collation_name) = \
#     648             CharacterSet.get_charset_info(collation=collation)
# --> 650 self._execute_query("SET NAMES '{0}' COLLATE '{1}'".format(
#     651     charset_name, collation_name))
#     653 try:
#     654     # Required for C Extension
#     655     self.set_character_set_name(charset_name)  # pylint: disable=E1101
#
# File ~/miniconda3/envs/datathon/lib/python3.11/site-packages/mysql/connector/connection.py:871, in MySQLConnection._execute_query(self, query)
#     862 """Execute a query
#     863
#     864 This method simply calls cmd_query() after checking for unread
#    (...)
#     868 Returns a dict()
#     869 """
#     870 self.handle_unread_result()
# --> 871 self.cmd_query(query)
#
# File ~/miniconda3/envs/datathon/lib/python3.11/site-packages/mysql/connector/connection.py:490, in MySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     488 if not isinstance(query, bytes):
#     489     query = query.encode('utf-8')
# --> 490 result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     492 if self._have_next_result:
#     493     raise errors.InterfaceError(
#     494         'Use cmd_query_iter for statements with multiple queries.')
#
# File ~/miniconda3/envs/datathon/lib/python3.11/site-packages/mysql/connector/connection.py:267, in MySQLConnection._send_cmd(self, command, argument, packet_number, packet, expect_response, compressed_packet_number)
#     265 if not expect_response:
#     266     return None
# --> 267 return self._socket.recv()
#
# File ~/miniconda3/envs/datathon/lib/python3.11/site-packages/mysql/connector/network.py:241, in BaseMySQLSocket.recv_plain(self)
#     239 packet_len = 0
#     240 while packet_len < 4:
# --> 241     chunk = self.sock.recv(4 - packet_len)
#     242     if not chunk:
#     243         raise errors.InterfaceError(errno=2013)
#
# KeyboardInterrupt:

# %%
book_df.loc[0]
# Out:
# 도서ID                                            SS_270312
# 등록일자                                           2017-09-13
# 수서방법                                                 학과신청
# 분류코드                                                  194
# ISBN                                        9782020658706
# 서명      Le courage de la verite :le gouvernement de so...
# 저자                                       Foucault, Michel
# 출판사                                             Gallimard
# 출판년도                                                 2009
# 소장위치                                                 4층인문
# Name: 0, dtype: object
