# %%
import pandas as pd
import numpy as np

# %%
# !ls
# Out:
# Main.ipynb

# %%
# 단행본(도서)정보.txt
book_df = pd.read_csv('../Data/단행본(도서)정보.txt', sep=',', encoding='EUC-KR')
book_df[:3]
# Out:
#         도서ID        등록일자    수서방법 분류코드           ISBN  \
# 0  SS_270312  2017-09-13    학과신청  194  9782020658706
# 1  SS_233793  2008-10-13  수서정보없음  160  9788995605189
# 2  SS_233788  2008-10-13  수서정보없음  160  9788995605189
#
#                                                   서명  \
# 0  Le courage de la verite :le gouvernement de so...
# 1                                         김나지움 논리학입문
# 2                                         김나지움 논리학입문
#
#                                저자        출판사  출판년도  소장위치
# 0                Foucault, Michel  Gallimard  2009  4층인문
# 1  Hegel, Georg Wilhelm Friedrich        용의숲  2008  보존서고
# 2  Hegel, Georg Wilhelm Friedrich        용의숲  2008  4층인문

# %%
book_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301151 entries, 0 to 301150
# Data columns (total 10 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   도서ID    301151 non-null  object
#  1   등록일자    301151 non-null  object
#  2   수서방법    301151 non-null  object
#  3   분류코드    301151 non-null  object
#  4   ISBN    301151 non-null  object
#  5   서명      301151 non-null  object
#  6   저자      291524 non-null  object
#  7   출판사     300948 non-null  object
#  8   출판년도    300966 non-null  object
#  9   소장위치    301151 non-null  object
# dtypes: object(10)
# memory usage: 23.0+ MB

# %%
book_df.isnull().sum() / len(book_df)
# Out:
# 도서ID    0.000000
# 등록일자    0.000000
# 수서방법    0.000000
# 분류코드    0.000000
# ISBN    0.000000
# 서명      0.000000
# 저자      0.031967
# 출판사     0.000674
# 출판년도    0.000614
# 소장위치    0.000000
# dtype: float64

# %%
# 각 열에서 가장 긴 데이터 길이 계산
max_lengths = book_df.astype(str).applymap(len).max()

# 결과 출력
print(max_lengths)
# Out:
# /tmp/ipykernel_11812/2139521444.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   max_lengths = book_df.astype(str).applymap(len).max()
# 도서ID      9
# 등록일자     10
# 수서방법      6
# 분류코드     16
# ISBN     13
# 서명      500
# 저자      153
# 출판사     210
# 출판년도     50
# 소장위치      4
# dtype: int64

# %%
top_25 = book_df.sort_values(by='출판년도').head(25)

# 결과 출력
display(top_25)
# Out:
#              도서ID        등록일자    수서방법        분류코드           ISBN  \
# 171462  SS_146279  1978-06-20  수서정보없음       951.7  9783203504674
# 183725  SS_254620  2002-06-18  수서정보없음       796.4  9784884700584
# 119430  SS_089883  2013-10-31  수서정보없음         973  9780070239876
# 54056   SS_184489  1995-05-30  수서정보없음       646.3              0
# 90523   SS_250073  1997-11-05  수서정보없음      422.03  9780415050777
# 154591  SS_188251  1995-06-14  수서정보없음      808.06              0
# 12603   SS_251851  1996-10-11  수서정보없음      025.04  9781883577919
# 117799  SS_249917  1997-10-27  수서정보없음         128  9780140444711
# 70350   SS_251852  1996-10-11  수서정보없음      025.04  9781883577872
# 45294   SS_262224  2001-11-06  수서정보없음  291.130952  9788908041936
# 45295   SS_262223  2001-11-06  수서정보없음  291.130952  9788908041936
# 228702  SS_262059  1998-07-30  수서정보없음       275.1              0
# 242284  SS_080269  2012-09-05    학과신청         102  9788976823809
# ...
